# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('car_data.csv')

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df_1 = df.loc[df['month'] == 1]

# %%
plt.plot(df_1['price'])

# %%
df_1.reset_index(inplace = True)

# %%
df_1.drop('index', axis = 1, inplace = True)
# Out:
# /var/folders/7_/hrpf2wd52k91vfg1qd2m7ch80000gn/T/ipykernel_7742/3289841515.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1.drop('index', axis = 1, inplace = True)

# %%
a = df.loc[df.mileage.str.contains('Inoperable') == True].index
df.drop(index = a, inplace = True)
df
# Out:
#      lot_number          condition       damage               mileage  price  \
# 0      35469733      Run and Drive    Front End  13918 miles (Actual)   5225
# 2      72632512  Enhanced Vehicles    Front End  42560 miles (Actual)   4200
# 3      72407282  Enhanced Vehicles    Front End  55308 miles (Actual)   3100
# 4      63624682  Enhanced Vehicles    Front End  77025 miles (Actual)   7600
# 5      48466322      Run And Drive    Front End  41546 miles (Actual)   7700
# ..          ...                ...          ...                   ...    ...
# 687    38995222  Enhanced Vehicles    Front End  73213 miles (Actual)   2750
# 688    36916062  Enhanced Vehicles    Front End  38742 miles (Actual)   6300
# 689    32736444         Stationary  Right Front  42279 miles (Actual)   4325
# 690    70016541      Run And Drive     Rear End  34898 miles (Actual)  11300
# 691    41808252      Run And Drive    Front End  42247 miles (Actual)  10900
#
#      day  month  year
# 0     23      1  2023
# 2     20      1  2023
# 3     20      1  2023
# 4     20      1  2023
# 5     20      1  2023
# ..   ...    ...   ...
# 687    5      5  2022
# 688    5      5  2022
# 689    6      5  2022
# 690    5      5  2022
# 691    5      5  2022
#
# [691 rows x 8 columns]

# %%
df.reset_index(drop = True, inplace = True)

# %%
# Out:
# 0      13918 miles (Actual)
# 1      42560 miles (Actual)
# 2      55308 miles (Actual)
# 3      77025 miles (Actual)
# 4      41546 miles (Actual)
#                ...
# 686    73213 miles (Actual)
# 687    38742 miles (Actual)
# 688    42279 miles (Actual)
# 689    34898 miles (Actual)
# 690    42247 miles (Actual)
# Name: mileage, Length: 691, dtype: object
