# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('volkswagen_gti_2017-2020.csv')

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df.rename(columns = {'vehicles':'vehicle_count'}, inplace = True)

# %%
df['avg_price'] = df['avg_price'].str.replace('$', '')
# Out:
# /var/folders/7_/hrpf2wd52k91vfg1qd2m7ch80000gn/T/ipykernel_46966/2729151896.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['avg_price'] = df['avg_price'].str.replace('$', '')

# %%
sns.histplot(data = df['price'])
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>
